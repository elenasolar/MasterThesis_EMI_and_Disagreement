# %% [markdown]
# # **Llama-3.1-8B-Classification, Attention & FFN -LoRa & Peft**
#
# ## **Classification of actual data; 2 Labels as scale**

# %%
# !pip install huggingface_hub
# !pip install -U bitsandbytes
# !pip install -U transformers
# !pip install -U accelerate
# !pip install -U peft
# !pip install -U trl
# !pip install pyarrow==18.1.0
# !pip install evaluate
# !pip install --upgrade wandb
# !pip install adapter-transformers
# Out:
# ...
#   Using cached transformers-4.53.1-py3-none-any.whl.metadata (40 kB)
# ...
# Using cached transformers-4.53.1-py3-none-any.whl (10.8 MB)
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# adapters 1.2.0 requires transformers~=4.51.3, but you have transformers 4.53.1 which is incompatible.
# ...
#   Using cached transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# ...
# Using cached transformers-4.51.3-py3-none-any.whl (10.4 MB)
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.53.1
#     Uninstalling transformers-4.53.1:
#       Successfully uninstalled transformers-4.53.1
# ...

# %%
# import packages

import numpy as np
import pandas as pd
import os
import random
import evaluate
import functools # ??
from tqdm import tqdm
import bitsandbytes as bnb
import wandb

import torch
import torch.nn as nn
import torch.nn.functional as F

from datasets import Dataset, DatasetDict
from peft import LoraConfig, PeftConfig, prepare_model_for_kbit_training, get_peft_model

from trl import SFTTrainer
from trl import setup_chat_format

import transformers
from transformers import (AutoModelForCausalLM,
                          AutoModelForSequenceClassification,
                        AutoTokenizer,
                        AutoModel,
                        AutoConfig,
                          BitsAndBytesConfig, 
                          TrainingArguments, 
                            Trainer,
                            DataCollatorWithPadding,
                          pipeline, 
                          logging)

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (accuracy_score, 
                             classification_report, 
                             confusion_matrix,
                            f1_score, balanced_accuracy_score)
from peft import PeftModel
from huggingface_hub import login
import matplotlib.pyplot as plt
import zipfile

# %%
os.getcwd()
# Out:
# '/home/jovyan/llama_final/Classification/two_labels/attention_FFN_LoRa'

# %% [markdown]
# ## **Authenticate for Hugging Face**

# %%
# Hugging face access

with open("../../../../login/hf_key.txt", 'r') as f: 
    HF_TOKEN = str(f.read())
    
login(token = HF_TOKEN)

torch.cuda.empty_cache()
torch.cuda.is_available()
#torch.cuda.device_count()
# Out:
# True

# %%
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %% [markdown]
# ## **Reimport Pretrained Model**

# %%
# file paths
base_model = "meta-llama/Llama-3.1-8B" 
finetuned_path = "final_Llama_3.1_8B_saved_model_2labels_scale_FFN"

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit = True, # enable 4 bit quantization
    bnb_4bit_quant_type = 'nf4', # information theoretically optimal dtype for normally distributed weights
    bnb_4bit_use_double_quant = True, # quantize quantized weights
    bnb_4bit_compute_dtype = torch.bfloat16 # optimized fp format for ML
)

# load base model
model = AutoModelForSequenceClassification.from_pretrained(
    base_model,
    quantization_config = quantization_config
)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at meta-llama/Llama-3.1-8B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Add LoRA adapter on top of it
model = PeftModel.from_pretrained(model, finetuned_path)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(finetuned_path, add_prefix_space=True)

tokenizer.pad_token_id = tokenizer.eos_token_id
tokenizer.pad_token = tokenizer.eos_token
model.config.pad_token_id = tokenizer.pad_token_id  
model.config.use_cache = False 
model.config.pretraining_pt = 1

# %%
# move model to gpu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

model.to(device)
# Out:
# PeftModelForSequenceClassification(
#   (base_model): LoraModel(
#     (model): LlamaForSequenceClassification(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
# ...

# %%
# some checks

print("Padding token:", tokenizer.pad_token)
print("Padding token ID:", tokenizer.pad_token_id)

print("Model Configuration:")
print(model.config)
# Out:
# Padding token: <|end_of_text|>
# Padding token ID: 128001
# Model Configuration:
# LlamaConfig {
#   "_attn_implementation_autoset": true,
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 131072,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128001,
#   "pretraining_pt": 1,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
# ...

# %% [markdown]
# # **Data**

# %%
subreddits = ["Ask_Politics", "Askpolitics", "PoliticalDebate", "PoliticalDiscussion", 
              "NeutralPolitics", "politics"]

subreddits_reduced = ["Ask_Politics", "Askpolitics", "PoliticalDebate", "PoliticalDiscussion", 
              "NeutralPolitics"]

subreddits_politics = ["politics"]

# %%
# reddit data

Ask_Pol_path = "../../../../data/new_preprocessing/Ask_Politics_new_preprocessing_com_rep.csv"
Askpol_path = "../../../../data/new_preprocessing/Askpolitics_new_preprocessing_com_rep.csv"
PolDis_path = "../../../../data/new_preprocessing/PoliticalDiscussion_new_preprocessing_com_rep.csv"
PolDeb_path = "../../../../data/new_preprocessing/PoliticalDebate_new_preprocessing_com_rep.csv"
NeuPol_path = "../../../../data/new_preprocessing/NeutralPolitics_new_preprocessing_com_rep.csv"

pol_path = "../../../../data/new_preprocessing/splitted_politics_data.zip"

# %%
# import data


Ask_Politics = pd.read_csv(Ask_Pol_path)
Askpolitics = pd.read_csv(Askpol_path)
PoliticalDiscussion = pd.read_csv(PolDis_path)
PoliticalDebate = pd.read_csv(PolDeb_path)
NeutralPolitics = pd.read_csv(NeuPol_path)


# politics from zip files
df_chunks = []
with zipfile.ZipFile(pol_path, 'r') as zf:
    file_list = zf.namelist()  # Get all file names in ZIP

    # Sort to maintain order (if needed)
    file_list.sort()  

    print("Files found in ZIP:", file_list)  # Debugging step

    for file in file_list:
        with zf.open(file) as f:
            df_chunk = pd.read_csv(f,  quotechar='"', encoding="utf-8")  
            df_chunks.append(df_chunk)  # Store the chunk


politics = pd.concat(df_chunks, ignore_index=True)

print(f"Successfully loaded {len(politics)} rows from {pol_path}")
# Out:
# Files found in ZIP: ['data_part_1.csv', 'data_part_2.csv', 'data_part_3.csv', 'data_part_4.csv', 'data_part_5.csv']
# Successfully loaded 4175294 rows from ../../../../data/new_preprocessing/splitted_politics_data.zip

# %%
# strip quotation marks
for col in ['msg_id_parent', 'msg_id_child', 'submission_id',
            'subreddit', 
            'body_child', 'body_parent', 'submission_text',
            'author_child', 'author_parent', 'author_submission']:
    if politics[col].dtype == "object":  # Apply only to string columns
        politics[col] = politics[col].str.strip('"')


for col in ['msg_id_parent', 'msg_id_child', 'submission_id',
            'subreddit', 
            'body_child', 'body_parent', 'submission_text',
            'author_child', 'author_parent', 'author_submission']:
    if PoliticalDiscussion[col].dtype == "object":  # Apply only to string columns
        PoliticalDiscussion[col] = PoliticalDiscussion[col].str.strip('"')

# %%
df_dict = {"Ask_Politics" : Ask_Politics,
           "Askpolitics" : Askpolitics,
           "PoliticalDiscussion" : PoliticalDiscussion,
           "PoliticalDebate" : PoliticalDebate,
           "NeutralPolitics" : NeutralPolitics,
           "politics" : politics}

# %%
label_dict = {0 : 'no_disagreement', 1: 'disagree'}

# %% [markdown]
# ## **Make Prompts**

# %%
# make text
model_data = {}

def create_training_data(data):

    result = []

    result = data[["msg_id_child", "msg_id_parent", "submission_id", 'body_parent', 'body_child']]
    result = result.rename(columns = {"body_parent" : 'comment', "body_child" : 'reply'})
    return result


for subr in subreddits:
    model_data[subr] = pd.DataFrame(create_training_data(df_dict[subr]))

# %%
model_data["Ask_Politics"]
# Out:
#       msg_id_child msg_id_parent submission_id  \
# 0          c7ecs2n       c7ecp8d        14m325
# 1          c7ecxpk       c7ecp8d        14m325
# 2          c7edsp8       c7edr13        14m26x
# 3          c7ee4yl       c7ee45j        14m26x
# 4          c7ee63a       c7ee45j        14m26x
# ...            ...           ...           ...
# 54257      kcank7h       eildsfz        b1fvxd
# 54258      kcpthf9       ffre1be        eufkoe
# 54259      kd3bh9v       jqjjy5q       14ot71b
# 54260      kd4b3a5       eh3fmh4        attjcv
# 54261      keipr74       jufqeli       15fn49a
#
#                                                  comment  \
# 0      Regarding Perry vs. Brown the current name of ...
# 1      Regarding Perry vs. Brown the current name of ...
# 2                           So what was wrong with  or ?
# 3      We will be adhering to the AskScience style of...
# 4      We will be adhering to the AskScience style of...
# ...

# %%
def make_prompt(row):

    prompt = " Comment: " + str(row["comment"]) + "; Reply: " + str(row["reply"])

    return prompt

for subr in subreddits:
    model_data[subr]['prompt'] = None
    model_data[subr]['prompt'] = model_data[subr].apply(lambda row: make_prompt(row), axis = 1)

# %%
model_data['politics']
# Out:
#         msg_id_child msg_id_parent submission_id  \
# 0            c0aeb6y       c0ae9r5         8tp50
# 1            c0aee4d       c0aeds9         8tp50
# 2            c0aeglj       c0aeds9         8tp50
# 3            c0aehqw       c0aeds9         8tp50
# 4            c0aegcb       c0aecro         8tp50
# ...              ...           ...           ...
# 4175289      kfmd52k       kfkh5ib       18uirzt
# 4175290      kforzbx       kfklsb6       18uirzt
# 4175291      kfp6tzv       kfmq5kr       18uirzt
# 4175292      kfp8xh8       kfp3d4v       18uirzt
# 4175293      kfpvec4       kfkiulh       18uirzt
#
#                                                    comment  \
# 0        O'Reilly was actually against FISA and Bush on...
# 1        Of course it's fine for Olbermann to occasiona...
# 2        Of course it's fine for Olbermann to occasiona...
# 3        Of course it's fine for Olbermann to occasiona...
# 4        waaah FOX NEWS, do you people have anything be...
# ...

# %%
# token length checks
#df['prompt_len'] = df['prompt'].apply(lambda x: len(x.split()))
#df['com_len'] = df['comment'].apply(lambda x: len(x.split()))
#df['rep_len'] = df['reply'].apply(lambda x: len(x.split()))
#df['len'] = df['com_len'] + df['rep_len']
#df['diff'] = df['prompt_len'] - df['len']
#df

# %% [markdown]
# # **Token Length Checks**

# %%
def find_longest_tokenized_text(df, tokenizer):
    # Calculate token lengths
    df['token_length'] = df['prompt'].apply(lambda x: len(tokenizer.encode(x, truncation=False)))
    
    # Find the row with the longest tokenized input
    max_row = df.loc[df['token_length'].idxmax()]
    
    print(f"Longest tokenized text has {max_row['token_length']} tokens.")

    return max_row['token_length']

# %%
max_length = {}

for subr in subreddits:
    print(subr)
    
    max_length[subr] = find_longest_tokenized_text(model_data[subr], tokenizer)
# Out:
# Ask_Politics
# Longest tokenized text has 3617 tokens.
# Askpolitics
# Longest tokenized text has 2496 tokens.
# PoliticalDebate
# Longest tokenized text has 2437 tokens.
# PoliticalDiscussion
# Longest tokenized text has 3833 tokens.

# %%
tokens_all = pd.DataFrame()

for subr in subreddits:
    
    tokens_all = pd.concat([tokens_all, model_data[subr]["token_length"]]).reset_index(drop = True)

tokens_all.rename(columns = {0 : "token_length"}, inplace = True)

type(tokens_all['token_length'][0])
# Out:
# numpy.float64

# %%
bin_edges = np.arange(0, tokens_all['token_length'].max() + 1, 1)

plt.figure(figsize=(7, 5))
plt.hist(tokens_all['token_length'], bins=bin_edges)

# Vertical line at 512 tokens
plt.axvline(x=1024, color="red")

# Set limits
plt.xlim(0, tokens_all['token_length'].max() + 300)

# Set titles and labels with larger fonts
#plt.title("Distribution of Token Length in Debagree Data", fontsize=18)
plt.xlabel("Number of Tokens", fontsize=16)
plt.ylabel("Frequency", fontsize=16)

# Increase tick label font size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Grid and layout
plt.grid(True)

# Save or show
plt.savefig("plots/TokenDistribution_Reddit.pdf", bbox_inches='tight')
plt.show()

# %%
len(tokens_all[tokens_all['token_length'] <= 1024]) / len(tokens_all)
# Out:
# 0.9970252255788244

# %%
tokens_all.to_csv("output/reddit_token_len.csv", index = False)

# %%
tokens_all = pd.read_csv("output/reddit_token_len.csv")
tokens_all
# Out:
#          token_length
# 0               249.0
# 1               224.0
# 2               108.0
# 3                53.0
# 4               103.0
# ...               ...
# 4958018          32.0
# 4958019          35.0
# 4958020         361.0
# 4958021          49.0
# 4958022          48.0
#
# [4958023 rows x 1 columns]

# %% [markdown]
# ### **Check Debagree Tokens**

# %%
debagree = pd.read_csv("../../../../data/new_preprocessing/debagree_new_preprocessing_com_rep.csv")
debagree = debagree[["label", "body_parent", "body_child", "msg_id_parent", "msg_id_child", "subreddit", "datetime", "exact_time"]].sort_values(by = "exact_time").reset_index(drop = True)

# keep integer labels
debagree['target'] = debagree['label']

# for readability, recode labels
int_to_label = {2: "agree", 1 : "neutral", 0 : "disagree"}
debagree.replace({"label": int_to_label}, inplace = True)

debagree
# Out:
#           label                                        body_parent  \
# 0       neutral  I live in rural Saskatchewan, Canada. We have ...
# 1       neutral  I live in rural Saskatchewan, Canada. We have ...
# 2       neutral  Convince her of what? That it's happening or t...
# 3      disagree  I think this prediction is about as valid as s...
# 4      disagree  Mann hasn't been honest in decades, so I'm cur...
# ...         ...                                                ...
# 42838   neutral  Not trying to spark an argument but a legitima...
# 42839     agree  Y'all saw Guilianis hail Mary right? Get his s...
# 42840     agree  Why don't I see ads holding Republicans accoun...
# 42841     agree  How about ... no? This is strange. Community o...
# 42842     agree  Can you recruit some white allies so you aren'...
#
#                                               body_child msg_id_parent  \
# 0      I'm in NE USA we've had 3 in two years...all e...       cnddov1
# ...

# %%
# make text

def create_training_data(data):

    result = []

    for idx, row in data.iterrows():
        #system_prompt = """You are a classification Chatbot. Given a comment and a reply, you classify whether the reply disagrees with the comment, or not. You only reply with either "disagree" or "no_disagreement" and nothing else."""
        comment = row["body_parent"]
        reply = row["body_child"]
        target = row["target"]
        result.append({'comment' : comment, 'reply': reply})
    
    return result

# save data
df_debagree = pd.DataFrame(create_training_data(debagree))
df_debagree
# Out:
#                                                  comment  \
# 0      I live in rural Saskatchewan, Canada. We have ...
# 1      I live in rural Saskatchewan, Canada. We have ...
# 2      Convince her of what? That it's happening or t...
# 3      I think this prediction is about as valid as s...
# 4      Mann hasn't been honest in decades, so I'm cur...
# ...                                                  ...
# 42838  Not trying to spark an argument but a legitima...
# 42839  Y'all saw Guilianis hail Mary right? Get his s...
# 42840  Why don't I see ads holding Republicans accoun...
# 42841  How about ... no? This is strange. Community o...
# 42842  Can you recruit some white allies so you aren'...
#
#                                                    reply
# 0      I'm in NE USA we've had 3 in two years...all e...
# 1      One hundred year flood just means a one in one...
# 2      That anthropocentric climate change is actuall...
# ...

# %%
df_debagree['prompt'] = None

def make_prompt(row):

    prompt = "Comment: " + row["comment"] + "; Reply: " + row["reply"]

    return prompt



df_debagree['prompt'] = df_debagree.apply(lambda row: make_prompt(row), axis = 1)
df_debagree
# Out:
#                                                  comment  \
# 0      I live in rural Saskatchewan, Canada. We have ...
# 1      I live in rural Saskatchewan, Canada. We have ...
# 2      Convince her of what? That it's happening or t...
# 3      I think this prediction is about as valid as s...
# 4      Mann hasn't been honest in decades, so I'm cur...
# ...                                                  ...
# 42838  Not trying to spark an argument but a legitima...
# 42839  Y'all saw Guilianis hail Mary right? Get his s...
# 42840  Why don't I see ads holding Republicans accoun...
# 42841  How about ... no? This is strange. Community o...
# 42842  Can you recruit some white allies so you aren'...
#
#                                                    reply  \
# 0      I'm in NE USA we've had 3 in two years...all e...
# 1      One hundred year flood just means a one in one...
# 2      That anthropocentric climate change is actuall...
# ...

# %%
find_longest_tokenized_text(df_debagree, tokenizer)
# Out:
# Longest tokenized text has 255 tokens.
# 255

# %%
df_debagree.to_csv("output/Debagree_token_len.csv", index = False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_debagree = pd.read_csv("output/Debagree_token_len.csv")

# %%
bin_edges = np.arange(0, df_debagree['token_length'].max() + 1, 1)

plt.figure(figsize=(7, 5))
plt.hist(df_debagree['token_length'], bins=bin_edges)

# Vertical line at 512 tokens
plt.axvline(x=512, color="red")

# Set limits
plt.xlim(0, df_debagree['token_length'].max() + 300)

# Set titles and labels with larger fonts
#plt.title("Distribution of Token Length in Debagree Data", fontsize=18)
plt.xlabel("Number of Tokens", fontsize=16)
plt.ylabel("Frequency", fontsize=16)

# Increase tick label font size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Grid and layout
plt.grid(True)

# Save or show
plt.savefig("plots/Debagree_TokenDistribution.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Restrict Interactions**

# %%
filtered_model_data = {}

for subr in subreddits:

    filtered_model_data[subr] = model_data[subr][model_data[subr]['token_length'] <= 1024].reset_index(drop = True)

    print(f"Removed {len(model_data[subr]) - len(filtered_model_data[subr])} in {subr}. Share: {(len(model_data[subr]) - len(filtered_model_data[subr])) / len(model_data[subr])}")
# Out:
# Removed 837 in Ask_Politics. Share: 0.015425159411743024
# Removed 36 in Askpolitics. Share: 0.005657708628005658
# Removed 92 in PoliticalDebate. Share: 0.010525111543301682
# Removed 4327 in PoliticalDiscussion. Share: 0.006476255476080361
# Removed 2215 in NeutralPolitics. Share: 0.04897192129117842
# Removed 7242 in politics. Share: 0.001734488637207344

# %% [markdown]
# # **Make predictions**

# %%
def make_predictions(model, df_test, subreddit, thresh):

    print(subreddit)
    
    model.eval()

    # Convert summaries to a list
    sentences = df_test.prompt.tolist()
    
    # Define the batch size
    batch_size = 32  # You can adjust this based on your system's memory capacity
    
    # Initialize an empty list to store the model outputs
    all_outputs = []
    
    # Process the sentences in batches
    for i in tqdm(range(0, len(sentences), batch_size)):
      # Get the batch of sentences
      batch_sentences = sentences[i:i + batch_size]
    
      # Tokenize the batch
      inputs = tokenizer(batch_sentences, return_tensors="pt", padding=True, truncation=True, max_length = 1024)
    
      # Move tensors to the device where the model is (e.g., GPU or CPU)
      inputs = {k: v.to('cuda' if torch.cuda.is_available() else 'cpu') for k, v in inputs.items()}
    
      # Perform inference and store the logits
      with torch.no_grad():
          outputs = model(**inputs)
          all_outputs.append(outputs['logits'])
          
    final_outputs = torch.cat(all_outputs, dim=0)
    probabilities = F.softmax(final_outputs, dim=1)
    
    probs_disagree = probabilities[:, 1]  # index 1 = 'disagree'
    predicted_labels = (probs_disagree > thresh).long()  # binary prediction
    certainty_scores = torch.max(probabilities, dim=1).values
    
    df_test['predictions_label_ft'] = predicted_labels.cpu().numpy()
    df_test['predictions_score_ft'] = certainty_scores.cpu().numpy()
    df_test['predictions_prob_disagree'] = probs_disagree.cpu().numpy()
    df_test['predictions_ft'] = df_test['predictions_label_ft'].apply(lambda l:label_dict[l])

    if subreddit in ['Ask_Politics', 'Askpolitics', 'NeutralPolitics', 'PoliticalDiscussion', 'PoliticalDebate']:
        df_test[['msg_id_parent', 'msg_id_child', 'submission_id', 'predictions_label_ft', 'predictions_score_ft', 
             'predictions_prob_disagree', 'predictions_ft']].to_csv(f"../../../../data/classified_labels/incl_true_probability/{subreddit}_Llama_3.1_8B_ft_classified.csv", index = False)

   

    
    return df_test

# %%
# apply

make_predictions(model, filtered_model_data['Ask_Politics'], "Ask_Politics", thresh = 0.65)
make_predictions(model, filtered_model_data['Askpolitics'], "Askpolitics", thresh = 0.65)
make_predictions(model, filtered_model_data['NeutralPolitics'], "NeutralPolitics", thresh = 0.65)
make_predictions(model, filtered_model_data['PoliticalDiscussion'], "PoliticalDiscussion", thresh = 0.65)
make_predictions(model, filtered_model_data['PoliticalDebate'], "PoliticalDebate", thresh = 0.65)
# Out:
# Ask_Politics
# 100%|██████████| 1670/1670 [1:16:21<00:00,  2.74s/it]
# Askpolitics
# 100%|██████████| 198/198 [08:26<00:00,  2.56s/it]
# NeutralPolitics
# 100%|██████████| 20744/20744 [12:42:31<00:00,  2.21s/it]
# PoliticalDebate
# 100%|██████████| 271/271 [11:28<00:00,  2.54s/it]
#      msg_id_child msg_id_parent submission_id  \
# 0         c0d5vj9       c0d5m53         9kkf8
# 1         c0d6c7g       c0d5m53         9kkf8
# 2         c0d6jvc       c0d5m53         9kkf8
# 3         c0d7f4g       c0d5zrm         9kncm
# 4         c7fpb3l       c7fp9wr        14r5kt
# ...           ...           ...           ...
# 8644      kfr2jzu       kfmqpen       18uokq0
# 8645      kfrb9ca       kfnu3qb       18upkh1
# 8646      kfrdz0h       kfor29i       18ut80y
# 8647      kfrgdfm       kfoqu1m       18ut80y
# 8648      kfrhpjf       kfobo0c       18ut80y
#
#                                                 comment  \
# 0     I think most things in the media are manufactu...
# ...

# %%
# example: for later adjusting the threshold

def adjust_threshold(df_test, new_thresh):
    # Adjust the predicted labels based on a new threshold
    new_predicted_labels = (df_test['predictions_score_ft'] > new_thresh).long()

    # Optionally, you can update the label column too
    df_test['predictions_label_ft'] = new_predicted_labels

    # You can also update predictions_ft if needed (if it's a mapped label like 'disagree'/'no_disagree')
    df_test['predictions_ft'] = df_test['predictions_label_ft'].apply(lambda l: label_dict[l])

    return df_test


# Call make_predictions initially with threshold 0.65
df_test = make_predictions(model, df_test, subreddit, thresh=0.65)

# Adjust threshold later to 0.5 (for example)
df_test = adjust_threshold(df_test, new_thresh=0.5)

# %%
labels = df["predictions_ft"]
labels

# %% [markdown]
# ## Politics:
#
# * Process in chunks and save in chunks

# %%
chunk_size = 750_000
politics_chunks = [filtered_model_data["politics"].iloc[i:i+chunk_size] for i in range(0, len(filtered_model_data["politics"]), chunk_size)]

# %%
for idx, chunk in enumerate(politics_chunks):

    df_test = make_predictions(model, chunk, "politics", thresh = 0.65)

    df_test[['msg_id_parent', 'msg_id_child', 'submission_id', 'predictions_label_ft', 'predictions_score_ft', 'predictions_prob_disagree',
             'predictions_ft']].to_csv(f"../../../../data/classified_labels/politics_{idx}_Llama_3.1_8B_ft_classified.csv", index = False)
# Out:
# politics
#  13%|█▎        | 2998/23438 [1:38:16<11:39:34,  2.05s/it]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 100%|██████████| 23438/23438 [8:01:11<00:00,  1.23s/it]
# /tmp/ipykernel_362/3786130469.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['predictions_label_ft'] = predicted_labels.cpu().numpy()
# /tmp/ipykernel_362/3786130469.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
len(politics_chunks)
# Out:
# 6

# %% [markdown]
# # **Reimport**

# %%
# change paths 

Ask_Pol_class = "../../../../data/classified_labels/incl_true_probability/Ask_Politics_Llama_3.1_8B_ft_classified.csv"
Askpol_class = "../../../../data/classified_labels/incl_true_probability/Askpolitics_Llama_3.1_8B_ft_classified.csv"
PolDis_class = "../../../../data/classified_labels/incl_true_probability/PoliticalDiscussion_Llama_3.1_8B_ft_classified.csv"
PolDeb_class = "../../../../data/classified_labels/incl_true_probability/PoliticalDebate_Llama_3.1_8B_ft_classified.csv"
NeuPol_class = "../../../../data/classified_labels/incl_true_probability/NeutralPolitics_Llama_3.1_8B_ft_classified.csv"

# %%
Ask_Politics_class = pd.read_csv(Ask_Pol_class)
Askpolitics_class = pd.read_csv(Askpol_class)
PoliticalDiscussion_class = pd.read_csv(PolDis_class)
PoliticalDebate_class = pd.read_csv(PolDeb_class)
NeutralPolitics_class = pd.read_csv(NeuPol_class)

# %%
politics_classified_parts = pd.DataFrame()

for i in range(6):

    temp = pd.read_csv(f"../../../../data/classified_labels/incl_true_probability/politics_{i}_Llama_3.1_8B_ft_classified.csv")
    politics_classified_parts = pd.concat([politics_classified_parts, temp]).reset_index(drop = True)
    
politics_classified_parts
# Out:
#         msg_id_parent msg_id_child submission_id  predictions_label_ft  \
# 0             c0ae9r5      c0aeb6y         8tp50                     0
# 1             c0aeds9      c0aee4d         8tp50                     0
# 2             c0aeds9      c0aeglj         8tp50                     1
# 3             c0aeds9      c0aehqw         8tp50                     1
# 4             c0aecro      c0aegcb         8tp50                     1
# ...               ...          ...           ...                   ...
# 4168047       kfkh5ib      kfmd52k       18uirzt                     0
# 4168048       kfklsb6      kforzbx       18uirzt                     0
# 4168049       kfmq5kr      kfp6tzv       18uirzt                     1
# 4168050       kfp3d4v      kfp8xh8       18uirzt                     0
# 4168051       kfkiulh      kfpvec4       18uirzt                     0
#
#          predictions_score_ft  predictions_prob_disagree   predictions_ft
# ...

# %%
#pd.read_csv(f"output_reddit/politics_1_Llama_3.1_8B_ft_classified.csv")

politics_classified_parts
# Out:
#         msg_id_parent msg_id_child submission_id  predictions_label_ft  \
# 0             c0ae9r5      c0aeb6y         8tp50                     0
# 1             c0aeds9      c0aee4d         8tp50                     0
# 2             c0aeds9      c0aeglj         8tp50                     1
# 3             c0aeds9      c0aehqw         8tp50                     1
# 4             c0aecro      c0aegcb         8tp50                     1
# ...               ...          ...           ...                   ...
# 4168047       kfkh5ib      kfmd52k       18uirzt                     0
# 4168048       kfklsb6      kforzbx       18uirzt                     0
# 4168049       kfmq5kr      kfp6tzv       18uirzt                     1
# 4168050       kfp3d4v      kfp8xh8       18uirzt                     0
# 4168051       kfkiulh      kfpvec4       18uirzt                     0
#
#          predictions_score_ft  predictions_prob_disagree   predictions_ft
# ...

# %%
print(len(Ask_Politics) == len(Ask_Politics_class))
print(len(Askpolitics) == len(Askpolitics_class))
print(len(PoliticalDiscussion) == len(PoliticalDiscussion_class))
print(len(PoliticalDebate) == len(PoliticalDebate_class))
print(len(NeutralPolitics) == len(NeutralPolitics_class))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(len(Ask_Politics) == len(Ask_Politics_class))
#       2 print(len(Askpolitics) == len(Askpolitics_class))
#       3 print(len(PoliticalDiscussion) == len(PoliticalDiscussion_class))
#
# NameError: name 'Ask_Politics' is not defined

# %%
classified_dict = {"Ask_Politics" : Ask_Politics_class,
                   "Askpolitics" : Askpolitics_class,
                   "PoliticalDiscussion" : PoliticalDiscussion_class,
                   "PoliticalDebate" : PoliticalDebate_class,
                   "NeutralPolitics" : NeutralPolitics_class,
                   "politics" : politics_classified_parts}

# %%
for key, value in classified_dict.items():
    print(key)
    print(len(value))
# Out:
# Ask_Politics
# 53425
# Askpolitics
# 6327
# PoliticalDiscussion
# 663806
# PoliticalDebate
# 8649
# NeutralPolitics
# 43015
# politics
# 4168052

# %% [markdown]
# ## **Label Shares**

# %%
def get_counts_and_shares(df, column):
    return df[column].value_counts().to_frame('Count').join(df[column].value_counts(normalize=True).to_frame('%')).reset_index()

# %%
def get_label_shares(df, label_col, valid_labels, subreddit):

    share = len(df[df[label_col].isin(valid_labels)]) / len(df)
    print(f"Valid Share of labels in {subreddit}: {share}")

    return df[label_col].value_counts().to_frame('Count').join(df[label_col].value_counts(normalize=True).to_frame('%')).reset_index()

# %%
label_shares = {}

for subr in subreddits:
    label_shares[subr] = get_label_shares(classified_dict[subr], 'predictions_ft', ['disagree', 'no_disagreement'], subr)
# Out:
# Valid Share of labels in Ask_Politics: 1.0
# Valid Share of labels in Askpolitics: 1.0
# Valid Share of labels in PoliticalDebate: 1.0
# Valid Share of labels in PoliticalDiscussion: 1.0
# Valid Share of labels in NeutralPolitics: 1.0
# Valid Share of labels in politics: 1.0

# %%
df_all = pd.DataFrame()

for subr in subreddits:
    df_all = pd.concat([df_all, classified_dict[subr]])

# %%
df_all['predictions_ft'].value_counts().to_frame('Count').join(df_all['predictions_ft'].value_counts(normalize=True).to_frame('%')).reset_index()
# Out:
#     predictions_ft    Count         %
# 0  no_disagreement  3619292  0.732165
# 1         disagree  1323982  0.267835

# %%
label_shares['Ask_Politics']
# Out:
#     predictions_ft  Count         %
# 0  no_disagreement  34141  0.639045
# 1         disagree  19284  0.360955

# %%
label_shares['Askpolitics']
# Out:
#     predictions_ft  Count         %
# 0  no_disagreement   3811  0.602339
# 1         disagree   2516  0.397661

# %%
label_shares['PoliticalDiscussion']
# Out:
#     predictions_ft   Count         %
# 0  no_disagreement  414084  0.623803
# 1         disagree  249722  0.376197

# %%
label_shares['PoliticalDebate']
# Out:
#     predictions_ft  Count         %
# 0         disagree   4570  0.528385
# 1  no_disagreement   4079  0.471615

# %%
label_shares['NeutralPolitics']
# Out:
#     predictions_ft  Count        %
# 0  no_disagreement  28768  0.66879
# 1         disagree  14247  0.33121

# %%
label_shares['politics']
# Out:
#     predictions_ft    Count         %
# 0  no_disagreement  3213962  0.771095
# 1         disagree   954090  0.228905

# %%
val_data = pd.read_csv("../../../Validation/data/majority_validation.csv")

val_data
# Out:
#    submission_id msg_id_parent msg_id_child  \
# 0         8we2i8       e2gbshk      e2go5cs
# 1        17p478l       k8h1qxn      k8ivjmx
# 2        181o366       kaf8us2      kahj2cn
# 3        18rqy2g       kf37doz      kf54umb
# 4         4dgyfc       d1qsqkm      d1r17xo
# 5        18fxb9q       kd28j8o      kdb3j9u
# 6          xqo2u       c5or5ik      c5p0n4r
# 7        17phvl2       k87wrac      k89o4tn
# 8         2p7xdk       cmu9elu      cmuk9pu
# 9         1ov3n2       ccw1rty      ccw2pn9
# 10       17v83gg       k99drl3      k9b6v5t
# 11        j6qf8a       g80ffxg      g80h2ma
# 12        15alin       c7kpiyi      c7kt3si
# 13        6ajyr0       dhf7aw2      dhf7gka
# 14        bkafep       emf6sht      emfv0d2
# 15        nt21kr       h0q0qop      h0q2eck
# 16        4gig2i       d2ildjm      d2im8ru
# 17         xsx54       c5pai5a      c5pbjqv
# 18        86tuay       dw7zcu3      dw82q4z
# 19        pxu6lc       hermw07      hetwgsp
# ...

# %%
get_label_shares(val_data[val_data['subreddit'] == 'Ask_Politics'], 'majority_label', ['disagree', 'no_disagreement'], "Ask_Politics")
# Out:
# Valid Share of labels in Ask_Politics: 1.0
#            label_e  Count    %
# 0  no_disagreement      8  0.8
# 1         disagree      2  0.2

# %%
get_label_shares(val_data[val_data['subreddit'] == 'Askpolitics'], 'majority_label', ['disagree', 'no_disagreement'], "Askpolitics")
# Out:
# Valid Share of labels in Askpolitics: 1.0
#            label_e  Count    %
# 0  no_disagreement      7  0.7
# 1         disagree      3  0.3

# %%
get_label_shares(val_data[val_data['subreddit'] == 'PoliticalDebate'], 'majority_label', ['disagree', 'no_disagreement'], "PoliticalDebate")
# Out:
# Valid Share of labels in PoliticalDebate: 1.0
#            label_e  Count    %
# 0  no_disagreement      8  0.8
# 1         disagree      2  0.2

# %%
get_label_shares(val_data[val_data['subreddit'] == 'PoliticalDiscussion'], 'majority_label', ['disagree', 'no_disagreement'], "PoliticalDiscussion")
# Out:
# Valid Share of labels in PoliticalDiscussion: 1.0
#            label_e  Count    %
# 0  no_disagreement      9  0.9
# 1         disagree      1  0.1

# %%
get_label_shares(val_data[val_data['subreddit'] == 'NeutralPolitics'], 'majority_label', ['disagree', 'no_disagreement'], "NeutralPolitics")
# Out:
# Valid Share of labels in NeutralPolitics: 1.0
#            label_e  Count    %
# 0  no_disagreement      7  0.7
# 1         disagree      3  0.3

# %%
get_label_shares(val_data[val_data['subreddit'] == 'politics'], 'majority_label', ['disagree', 'no_disagreement'], "politics")
# Out:
# Valid Share of labels in politics: 1.0
#            label_e  Count    %
# 0  no_disagreement      8  0.8
# 1         disagree      2  0.2
